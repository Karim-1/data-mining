# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import seaborn as sns
import random
import math
import missingno as msno
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import matplotlib as mpl
from matplotlib import pyplot as plt
from wordcloud import WordCloud
from sklearn.metrics import accuracy_score, log_loss
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC, LinearSVC
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

# %%
# Import and read data as pandas dataframe.
gender_survived = pd.read_csv("gender_submission.csv")
test = pd.read_csv("test.csv")
train = pd.read_csv("train.csv")

# Merge all data.
test.insert(1,'Survived',gender_survived['Survived'])
data = train.append(test, sort=False)
data = data.reset_index(drop=True)
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
# The column 'PassengerID' does not contain information about the passenger.
# Remove column
data = data.drop(columns=['PassengerId'])

# %%
# The missing values can be seen as white lines.
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
for gender in ['male','female']:
    data.Pclass[data.Sex == gender].plot(kind="kde")
plt.title("Gender density per class")
plt.legend(("Male","Female"))
plt.show()

# Histogram

# %%
# Print how many missing values each column has if there are missing values.
for var in data:
    col = data[var]
    missing = col.isnull().values.sum()
    if missing >0:
        print('the number is missing values in', var, 'is', col.isnull().values.sum())
        
# Alleen dit, geen plot
# Out:
# the number is missing values in Age is 263
# the number is missing values in Fare is 1
# the number is missing values in Cabin is 1014
# the number is missing values in Embarked is 2

# %% [markdown]
# There are 4 columns with missing values. Fill these values in by looking at other catgorei whith which they correlate. For instance 'Fare' might have a high correlation with 'Pclass' . So give the person with a missing 'Fare' value the average 'Fare' of people in their 'Pclass'. Start with the columns with the least missing values.

# %%
# Produce correlation heatmap, to see which columns correlate with the age.
def make_corrmap(data, vactor):
    corrmat = data.corr()
    k = 20 #Number of variables for heat map with largest correlation.
    cols = corrmat.nlargest(k, vactor)[vactor].index
    f, ax = plt.subplots(figsize=(14, 10))
    sns.heatmap(data[cols].corr(), vmax=1, square=True, annot=True)

# Fare has highest correlation with Pclass. 
# Use the avergae Fare of people with the same Pclasss to fill in missing value.
make_corrmap(data, 'Fare')

# %%
# Plot illustartes our correlation findings
Fare_1 = train.loc[data.Pclass ==1]["Fare"]
Fare_2 = train.loc[data.Pclass ==2]["Fare"]
Fare_3 = train.loc[data.Pclass ==3]["Fare"]

plt.hist([Fare_1, Fare_2, Fare_3], bins = 20, histtype = 'step', label = ['First class', 'Second class', 'Third class'])
plt.legend()
plt.title('The class per ticket price')
plt.xlabel('Fare')
plt.ylabel('Number of people')
plt.show()

for c in list(set(data['Pclass'])):
    data.Fare[data.Pclass == c].plot(kind='kde')
    
plt.title('The class per ticket price')
plt.legend(('First', 'Second','Third'))
plt.xlabel('Fare')
plt.ylabel('Number of people')
plt.xlim((0, 300))
plt.show()

# %%
# FARE
# Give missing fare values the mean fare value for the class they are in.
indx_nan = data.loc[pd.isna(data["Fare"]), :].index
clas = data['Pclass'].loc[indx_nan[0]]
fare_of_class = data.loc[data.Pclass == clas]["Fare"]
data.Fare.fillna(np.mean(fare_of_class), inplace = True)

# %% [markdown]
# The following column with the least missing values is 'Embarked'. Exploter relation with 'Sex', 'Fare', 'Ticket number'

# %%
# Plot shows that by far most people embarked from S and that gender does not really matter.

p = sns.countplot(x = "Embarked", hue = "Sex", data = data)
p.set_xticklabels(["S","C","Q"])
p.legend(labels = ["Male", "female"])
p.set_title('Male/Female passengers per Embarking point')

# Because the embarked data is only missing for two passengersm,
# we give these people the most frequently occuring value in the dataset.
data.Embarked.fillna(data.Embarked.mode()[0], inplace = True)

# %% [markdown]
# The missing values of 'Cabin' are in such abundance that predicting them would likely be highly incorrect.

# %%
sns.catplot(x='Pclass', y='Cabin',data=data)

# %%
# Give all nan cabins the same name
data.Cabin = data.Cabin.fillna('NO_CABIN')

# %% [markdown]
# The last column with many missing values is the column 'Age'. This column is correlating with most other columns. So before we make age predictions we first create some additional columns.

# %%
# Most people are third class passengers and about a quarter of the passengers are first class 
classes = data.Pclass.value_counts().tolist()
first = classes[1]
second = classes[2]
third = classes[0]

labels = 'First', 'Second', 'Third'
sizes = [first, second, third]

fig1, ax1 = plt.subplots()
plt.pie(sizes, labels=labels, startangle=90, autopct='%1.1f%%')
plt.axis('equal') 
plt.title('Distribution of Classes')
plt.show()

# %%
Sur_Age = train.loc[train.Survived == 1]["Age"]
Dead_Age = train.loc[train.Survived == 0]["Age"]

plt.hist([Sur_Age, Dead_Age], bins = 60, histtype = 'barstacked', label = ['Survived', 'Died'])
plt.title('Distribution if people per age, showing number of Survivors.')
plt.xlabel('Age')
plt.ylabel('Number of people')
plt.legend()
plt.show()

# %%
Age_1 = train.loc[data.Pclass ==1]["Age"]
Age_2 = train.loc[data.Pclass ==2]["Age"]
Age_3 = train.loc[data.Pclass ==3]["Age"]

plt.hist([Age_1, Age_2, Age_3], bins = 25, histtype = 'step', label = ['First', 'Second', 'Third'])
plt.legend()
plt.xlabel('Age')
plt.ylabel('Number of people')
plt.title('The age per class')
plt.show()

for c in list(set(data['Pclass'])):
    data.Age[data.Pclass == c].plot(kind='kde')
    
plt.title('Age density per class')
plt.legend(('First', 'Second','Third'))
plt.show()


p = sns.distplot(data['Age'],bins=30)
p.set_title('Age density of Passengers')
# Out:
# C:\Users\Marlon\AppData\Roaming\Python\Python38\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Age density of Passengers')

# %% [markdown]
# I would like to use multivariate linear regression to predict a passengers age. For this the categorical columns need to be numerical.

# %%
# Make all columns of which we no longer plan to extract additional data numerical.
data['Embarked'] = LabelEncoder().fit_transform(data['Embarked'])
data['Sex'] = LabelEncoder().fit_transform(data['Sex'])
data['Cabin'] = LabelEncoder().fit_transform(data['Cabin'])

# %%
data
# Out:
#       Survived  Pclass                                               Name  \
# 0            0       3                            Braund, Mr. Owen Harris
# 1            1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            1       3                             Heikkinen, Miss. Laina
# 3            1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304         0       3                                 Spector, Mr. Woolf
# 1305         1       1                       Oliva y Ocana, Dona. Fermina
# 1306         0       3                       Saether, Mr. Simon Sivertsen
# 1307         0       3                                Ware, Mr. Frederick
# 1308         0       3                           Peter, Master. Michael J
#
#       Sex   Age  SibSp  Parch              Ticket      Fare  Cabin  Embarked
# ...

# %%
# Make column with only last_names
names = data['Name'].copy(deep = True)
for row in range(len(data)):
    name = names[row]
    splitted = name.split()
    last_name = splitted[0]
    last_name = last_name[:-1]
    names.loc[row] = last_name.lower()
data['Last_names'] = names
# Make numerical.
data['Last_names'] = LabelEncoder().fit_transform(data['Last_names'])

# Make column with only titles
data['Title'] = data.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip().lower()) 
# Make numerical.
data['Title'] = LabelEncoder().fit_transform(data['Title'])

# %%
# The ticket columns consits of two possible elements: a sting prefix, and the actual ticket number.
# Make a column with only the tickets numbers.

# Make a columns with only the ticket numbers.
cleaned_tickets = data['Ticket'].copy(deep = True)
for row in range(len(data)):
    ticket = cleaned_tickets[row]
    if isinstance(ticket, int):
        continue
    if ticket.isdigit():
        cleaned_tickets[row] = int(ticket)
    else:
        splitted = ticket.split()
        if splitted[-1].isdigit(): 
            cleaned_tickets.loc[row] = int(splitted[-1])

# Collect the indices of rows which are not integers. 
# These instances are 'LINE' and are only in the training set.
to_be_removed_rows = []
for i in range(len(cleaned_tickets)):
    if not isinstance(cleaned_tickets[i], int):
        to_be_removed_rows.append(i)
        
data['Tickets_nr'] = cleaned_tickets

# %%
# Extract the train and test set, and remove the rows where the ticket nr is not an integer.
train = data.iloc[0:len(train)]
test = data.iloc[len(train):]

train = train.drop(train.index[to_be_removed_rows])
train = train.reset_index(drop=True)

# %%
# Merge all data again, but keep track of where the test and training set are.
data = train.append(test, sort=False)
data = data.reset_index(drop=True)

# %%
# We can use the last name and ticket number column to find family members which are not directly related.
# People with the same or consecutive ticket numbers and same last name are likely family.

# make a dataframe and set all values to 0
cousins = data['Sex'].copy(deep = True)
for i in range(len(cousins)):
    cousins.loc[i] = 0

# If another person has the same lastname and a neghbouring ticket (within a range of 10), then they are considered family
ticks = data['Tickets_nr']
names = data['Last_names']
for person_id in range(len(cousins)):
    family_members = 0
    ticket = data['Tickets_nr'][person_id]
    last_name = data['Last_names'][person_id]
    for passenger_id in range(len(cousins)):
#         if you find the person itself, continue
        if passenger_id == person_id:
            continue
        if last_name == names[passenger_id] and ticket-10 <= ticks[person_id] <= ticket+10:
            family_members+=1
    cousins.loc[person_id] = family_members
    
#  Add column to dataframe
data['Cousins'] = cousins

# %%
# All useable data is removed from data column, remove column
data = data.drop(columns=['Name'])

# %% [markdown]
# # Predict the missing ages using linear regression

# %%
# Produce correlation heatmap, to see which columns correlate with the age.
def make_corrmap(data, vactor):
    corrmat = data.corr()
    k = 20 #Number of variables for heat map with largest correlation.
    cols = corrmat.nlargest(k, vactor)[vactor].index
    f, ax = plt.subplots(figsize=(14, 10))
    sns.heatmap(data[cols].corr(), vmax=1, square=True, annot=True);

make_corrmap(data, 'Age')

# Conclusion all available variables have correlation, but categorica variables are not suitable for this heatmap.
# The variable Title, Sex, Last_names, Survived, Embarked,and Pclass are actually not suitable for multivariate regression beacuse they are categorical.

# %%
# Make a age testing dataset with only the passengers of whom the age is known.
pred_age = data.copy(deep=True)
index_ageless = []
# Get all indices of agless people.
for row in range(len(pred_age)):
    if math.isnan(pred_age['Age'][row]):
        index_ageless.append(row)
pred_age = pred_age.drop(pred_age.index[index_ageless])
pred_age = pred_age.reset_index(drop=True)

# %%
# Inititally only the numerical columsn were used, but after some testing the accuracy went up if the columsn 'Sex' and 'Title' were also used
# Make a linear regression model for the prediction of age.
reg = linear_model.LinearRegression()
reg.fit(pred_age[['Title','Sex','Fare','Parch', 'Cousins','SibSp']],pred_age['Age'])
# Out:
# LinearRegression()

# %%
# Test performance of age predictor.
# import sklearn.metrics as m

correct = 0
sum_square_error_pred = 0
real_ages = []
pred_ages = []
for i in range(len(pred_age)):
    true_age = pred_age['Age'][i]
    Title = data['Title'][i]
    Fare = data['Fare'][i]
    Sex = data['Sex'][i]
    Parch = data['Parch'][i]
    Cousins = data['Cousins'][i]
    SibSp = data['SibSp'][i]
    pred = np.round(reg.predict([[Title,Sex, Fare, Parch, Cousins, SibSp]]))
    real_ages.append(true_age)
    pred_ages.append(pred)
#     Correct if age is guessed within 3 years
    if true_age - 3 <= pred <= true_age + 3:
        correct+=1
# print(len(real_ages))
# print(len(pred_ages))
print("The mean squared error of the age predictor is", mean_squared_error(real_ages, pred_ages))
print('The age predictor is correct in', (correct/len(pred_age))*100, '% of the cases')



# Test performance of random distributed guesser

def age_guesser():
    correct = 0
    real_age = []
    guessed_age = []
    sum_square_error_pred = 0
    for i in range(len(pred_age)):
        true_age = pred_age['Age'][i]
        real_age.append(true_age)
        row = random.randint(0, len(pred_age)-1)
        guess = pred_age['Age'][row]
#         sum_square_error_pred += (guess - true_age )**2
        guessed_age.append(guess)
        
        if true_age-3 <= guess <= true_age+3:
            correct+=1
    return(correct, real_age, guessed_age)

correct_guesses = []
mean_squared_errors = []
for i in range(10):
    cor, real_age, guessed_age = age_guesser()
    correct_guesses.append(cor)
    mean_squared_errors.append(mean_squared_error(real_age, guessed_age))

average_correct = np.mean(correct_guesses)
average_mean_squeared_error = np.mean(mean_squared_errors)
    

# # MSE_m = m.mean_squared_error(age, predict)

# # rand_p = np.zeros(len(age))

# # for i in range(len(age)):
# #     rand_p[i] = random.choice(age)
    
# # MSE_r = m.mean_squared_error(age, rand_p)    

# # print('MSE model is ', MSE_m, 'MSE random is', MSE_r)


print("The mean squared error of the random guesser isis", average_mean_squeared_error)
print('the random age guesser is correct in', (average_correct/len(pred_age))*100, '% of the cases')
# Out:
# The mean squared error of the age predictor is 239.6648369481766
# The age predictor is correct in 19.001919385796544 % of the cases
# The mean squared error of the random guesser isis 412.94271451055664
# the random age guesser is correct in 15.834932821497121 % of the cases

# %%
# The age prediction model has a better performance and a lower mean squared error.
# Meaning that it is better at predicting a passengers age, use this technnique to fill in missing values.
index_ageless = []
for row in range(len(data)):
    if math.isnan(data['Age'][row]):
        index_ageless.append(row)

for i in index_ageless:
    Title = data['Title'][i]
    Fare = data['Fare'][i]
    Sex = data['Sex'][i]
    Parch = data['Parch'][i]
    Cousins = data['Cousins'][i]
    SibSp = data['SibSp'][i]
    pred = np.round(reg.predict([[Title, Sex, Fare, Parch, Cousins, SibSp]]))
    data.loc[i, 'Age'] = pred
data
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch              Ticket      Fare  \
# 0            0       3    1  22.0      1      0           A/5 21171    7.2500
# 1            1       1    0  38.0      1      0            PC 17599   71.2833
# 2            1       3    0  26.0      0      0    STON/O2. 3101282    7.9250
# 3            1       1    0  35.0      1      0              113803   53.1000
# 4            0       3    1  35.0      0      0              373450    8.0500
# ...        ...     ...  ...   ...    ...    ...                 ...       ...
# 1300         0       3    1  32.0      0      0           A.5. 3236    8.0500
# 1301         1       1    0  39.0      0      0            PC 17758  108.9000
# 1302         0       3    1  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 1303         0       3    1  32.0      0      0              359309    8.0500
# 1304         0       3    1  20.0      1      1                2668   22.3583
#
# ...

# %%
data['Ticket'] = LabelEncoder().fit_transform(data['Ticket'])
msno.matrix(data)
# All missing data is now complete and using numbers to represent categories.
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch  Ticket      Fare  Cabin  \
# 0            0       3    1  22.0      1      0     720    7.2500    185
# 1            1       1    0  38.0      1      0     815   71.2833    106
# 2            1       3    0  26.0      0      0     913    7.9250    185
# 3            1       1    0  35.0      1      0      65   53.1000     70
# 4            0       3    1  35.0      0      0     649    8.0500    185
# ...        ...     ...  ...   ...    ...    ...     ...       ...    ...
# 1300         0       3    1  32.0      0      0     711    8.0500    185
# 1301         1       1    0  39.0      0      0     833  108.9000     64
# 1302         0       3    1  38.5      0      0     871    7.2500    185
# 1303         0       3    1  32.0      0      0     579    8.0500    185
# 1304         0       3    1  20.0      1      1     262   22.3583    185
#
#       Embarked  Last_names  Title Tickets_nr  Cousins
# ...

# %%
train = data.iloc[0:len(train)]
test = data.iloc[len(train):]

# %%
train
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0           0       3    1  22.0      1      0     720   7.2500    185
# 1           1       1    0  38.0      1      0     815  71.2833    106
# 2           1       3    0  26.0      0      0     913   7.9250    185
# 3           1       1    0  35.0      1      0      65  53.1000     70
# 4           0       3    1  35.0      0      0     649   8.0500    185
# ..        ...     ...  ...   ...    ...    ...     ...      ...    ...
# 882         0       2    1  27.0      0      0     130  13.0000    185
# 883         1       1    0  19.0      0      0      18  30.0000     40
# 884         0       3    0  20.0      1      2     922  23.4500    185
# 885         1       1    1  26.0      0      0      11  30.0000     77
# 886         0       3    1  32.0      0      0     642   7.7500    185
#
#      Embarked  Last_names  Title Tickets_nr  Cousins
# 0           2         100     12      21171        1
# ...

# %%
clf = RandomForestClassifier(n_estimators=600,
                             min_samples_split=5,
                             min_samples_leaf=1,
                             n_jobs=-1)

train_data =train
col_train = train_data.drop(['Survived'], axis = 1)
surv_train = train_data['Survived']

test_data = test
col_test = test_data.drop(['Survived'], axis = 1)
surv_test = test_data['Survived']

# %%
clf.fit(col_train,  np.ravel(surv_train))
print("Random Forest Accuracy: "+repr(round(clf.score(col_test, surv_test) * 100, 2)) + "%")
clf = RandomForestClassifier(n_estimators=600,
                             min_samples_split=5,
                             min_samples_leaf=1,
                             n_jobs=-1)
result_rf=cross_val_score(clf, col_train, surv_train, cv=10,scoring='accuracy')
print(result_rf)
print('The cross validated score for Random forest is:',round(result_rf.mean()*100,2))
# Out:
# Random Forest Accuracy: 87.32%
# [0.84269663 0.85393258 0.71910112 0.88764045 0.88764045 0.84269663
#  0.83146067 0.80681818 0.84090909 0.86363636]
# The cross validated score for Random forest is: 83.77

# %%
# scores = []
# for i in range(100):
#     clf.fit(col_train,  np.ravel(surv_train))
#     score = repr(round(clf.score(col_test, surv_test) * 100, 2))
#     print(score)

# %%
# result = clf.predict(col_test)
# submission = pd.DataFrame({'PassengerId':gender_survived.PassengerId,'Survived':result})
# submission.Survived = submission.Survived.astype(int)
# print(submission.shape)
# filename = 'Titanic Predictions.csv'
# submission.to_csv(filename,index=False)
# print('Saved file: ' + filename)

# %%
# # Most people are third class passengers and about a quarter of the passengers are first class 
# gender =  data.Sex.value_counts().tolist()
# male = gender[0]
# female = gender[1]

# labels = 'Male', 'Female'
# sizes = [male, female]

# fig1, ax1 = plt.subplots()
# plt.pie(sizes, labels=labels, startangle=90, autopct='%1.1f%%')
# plt.axis('equal') 
# plt.title('Distribution of gender')
# plt.show()

# %%
# male_pr = (data[data.Sex == 0].Survived == 1).value_counts()[1]/len(data.Sex) * 100
# female_pr = (data[data.Sex == 1].Survived == 1).value_counts()[1]/len(data.Sex) * 100

# sex_perc_df = pd.DataFrame(
#     { "% Survived":{"male": male_pr,"female": female_pr},  "% Died":{"male": 100-male_pr,"female": 100-female_pr}})
# sex_perc_df.plot.bar().set_title("% of male and female survived and died")
# plt.show()

# %%
all_data = data
label_data = all_data.drop(['Survived'], axis = 1)
surv_data = all_data['Survived']

# %%
clf = RandomForestClassifier()
x_train, x_test, y_train, y_test = train_test_split(label_data, surv_data, test_size=0.2)
clf.fit(x_train,  np.ravel(y_train))
print("RF Accuracy: "+repr(round(clf.score(x_test, y_test) * 100, 2)) + "%")


result_rf=cross_val_score(clf,col_train,surv_train,cv=10,scoring='accuracy')
print(result_rf)
print('The cross validated score for Random forest is:',round(result_rf.mean()*100,2))
# y_pred = cross_val_predict(clf,x_train,y_train,cv=10)
# print(y_pred)
# sns.heatmap(confusion_matrix(y_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
# plt.title('Confusion_matrix for RF', y=1.05, size=15)
# Out:
# RF Accuracy: 87.36%
# [0.88764045 0.84269663 0.73033708 0.88764045 0.88764045 0.83146067
#  0.83146067 0.80681818 0.88636364 0.85227273]
# The cross validated score for Random forest is: 84.44

# %%
rf_score=[]
cross_val_rf = []
for i in range(10):
    clf = RandomForestClassifier()
    clf.fit(col_train,  np.ravel(surv_train))
    sc = round(clf.score(col_test, surv_test) * 100, 2)
    rf_score.append(sc)
    
    result_rf=cross_val_score(clf,col_train,surv_train,cv=10,scoring='accuracy')
    cross_val_rf.append(round(result_rf.mean()*100,2))
    
print('average accuracy RF is', np.mean(rf_score))
print('avergae cross_val_rf is', np.mean(cross_val_rf))

SVM_score=[]
cross_val_SVM = []
for i in range(10):
    SVM = make_pipeline(StandardScaler(),LinearSVC(dual=False, linearsvc__loss = 'hinge', 
                                                   linearsvc__multi_class = 'crammer_singer',
                                                   linearsvc__penalty = 'l1'))
    SVM.fit(col_train,  np.ravel(surv_train))
    sc = round(SVM.score(col_test, surv_test) * 100, 2)
    SVM_score.append(sc)
    
    result_rf=cross_val_score(SVM,col_train,surv_train,cv=10,scoring='accuracy')
    cross_val_SVM.append(round(result_rf.mean()*100,2))
    
print('average accuracy SVM is', np.mean(SVM_score))
print('avergae cross_val_SVM is', np.mean(cross_val_SVM))


y_pred = cross_val_predict(clf,col_train,surv_train,cv=10)
sns.heatmap(confusion_matrix(col_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
plt.title('Confusion_matrix for random forest', y=1.05, size=15)
# Out:
# average accuracy RF is 86.578
# avergae cross_val_rf is 83.96799999999999
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-20036d739972> in <module>
#      16 cross_val_SVM = []
#      17 for i in range(10):
# ---> 18     SVM = make_pipeline(StandardScaler(),LinearSVC(dual=False, linearsvc__loss = 'hinge',
#      19                                                    linearsvc__multi_class = 'crammer_singer',
#      20                                                    linearsvc__penalty = 'l1'))
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %%
clf = RandomForestClassifier()
# clf.fit(col_train,  np.ravel(surv_train))
# print("NB Accuracy: "+repr(round(clf.score(col_test, surv_test) * 100, 2)) + "%")
# result_rf=cross_val_score(clf,col_train,surv_train,cv=10,scoring='accuracy')
# print('The cross validated score for GNB is:',round(result_rf.mean()*100,2))

y_pred = cross_val_predict(clf,col_train,surv_train,cv=10)
sns.heatmap(confusion_matrix(surv_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
plt.title('Confusion_matrix for random forest', y=1.05, size=15)

# %%
y_pred = cross_val_predict(SVM,col_train,surv_train,cv=10)
sns.heatmap(confusion_matrix(surv_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
plt.title('Confusion_matrix for SVM', y=1.05, size=15)

# %%
# linear SVM!!
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_classification

SVM = make_pipeline(StandardScaler(),LinearSVC(dual=False))


x_train, x_test, y_train, y_test = train_test_split(label_data, surv_data, test_size=0.2)
SVM.fit(x_train,  np.ravel(y_train))
print("SVM Accuracy: "+repr(round(SVM.score(x_test, y_test) * 100, 2)) + "%")

SVM.fit(col_train,  np.ravel(surv_train))
print("SVM Accuracy: "+repr(round(SVM.score(col_test, surv_test) * 100, 2)) + "%")

result_rf=cross_val_score(SVM, col_train, surv_train, cv=10,scoring='accuracy')
print(result_rf)
print('The cross validated score for SVM is:',round(result_rf.mean()*100,2))
# Out:
# SVM Accuracy: 85.82%
# SVM Accuracy: 94.98%
# [0.82022472 0.80898876 0.7752809  0.85393258 0.79775281 0.7752809
#  0.78651685 0.79545455 0.82954545 0.82954545]
# The cross validated score for SVM is: 80.73

# %%
# TODO fix die mean squared error

# %%
# def test_hyperparameters_rf(i,j,etc, test_parameter):
#     result_rf=cross_val_score(clf,col_train,surv_train,cv=10,scoring='accuracy')
#     print(result_rf)
#     print('The cross validated score for Random forest is:',round(result_rf.mean()*100,2))


clf.fit(col_train,  np.ravel(surv_train))
print("Random Forest Accuracy: "+repr(round(clf.score(col_test, surv_test) * 100, 2)) + "%")
clf = RandomForestClassifier()

# clf = RandomForestClassifier(n_estimators=600,
#                              min_samples_split=5,
#                              min_samples_leaf=1,
#                              n_jobs=-1)


result_rf=cross_val_score(clf, col_train, surv_train, cv=10,scoring='accuracy')
print(result_rf)
print('The cross validated score for Random forest is:',round(result_rf.mean()*100,2))

# Geef alles default options, and  1by one decid eon the hyperparameters. Bad about this is that parameters might interact and thta is not tested in this manner

# %%
clf = RandomForestClassifier()
clf.fit(col_train,  np.ravel(surv_train))
result = clf.predict(col_test)

submission = pd.DataFrame({'PassengerId':gender_survived.PassengerId,'Survived':result})
submission.Survived = submission.Survived.astype(int)
print(submission.shape)
filename = 'Titanic Predictions_152.csv'
submission.to_csv(filename,index=False)
print('Saved file: ' + filename)
# submission

# %%
surv_test

# %% [markdown]
# # compute hyperparameters

# %%
from sklearn import datasets, svm
from sklearn.model_selection import GridSearchCV

clf = RandomForestClassifier()
print(clf.get_params().keys())

# parameters = {'n_estimators':[200, 300, 400, 500,600,700, 800, 900], 'min_samples_split':[2,4,6,8,10,12], 'min_samples_leaf':[1,2,4,6,8]}

parameters = {'n_estimators':[200, 300], 'min_samples_split':[2,4]}

# class weight, niet gerelateerd, alle classes even zwaar wegen
clf = GridSearchCV(clf, parameters)

clf.fit(label_data,  np.ravel(surv_data))
clf.best_params_
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])
# {'min_samples_split': 4, 'n_estimators': 300}

# %%
# clf = RandomForestClassifier(bootstrap = True,
#                              max_features = 'sqrt',
#                              min_samples_leaf = 2,
#                              min_samples_split = 4,
#                              n_estimators = 200,
#                              n_jobs = -1,
#                              oob_score = True,
#                              warm_start = False)

# %%
from sklearn import datasets, svm
from sklearn.model_selection import GridSearchCV

SVM = make_pipeline(StandardScaler(),LinearSVC(dual=False))
print(SVM.get_params().keys())

parameters = {'linearsvc__penalty':['l1', 'l2'], 'linearsvc__loss':['hinge', 'squared_hinge'], 'linearsvc__multi_class':['ovr', 'crammer_singer']}


# parameters = {'linearsvc__penalty':['l1', 'l2']}


# class weight, niet gerelateerd, alle classes even zwaar wegen
SVM = GridSearchCV(SVM, parameters)

# clf.fit(label_data,  np.ravel(surv_data))
SVM.fit(label_data,  np.ravel(surv_data))
SVM.best_params_

SVM_score=[]
cross_val_SVM = []
for i in range(10):
    SVM.fit(col_train,  np.ravel(surv_train))
    sc = round(SVM.score(col_test, surv_test) * 100, 2)
    SVM_score.append(sc)
    
    result_rf=cross_val_score(SVM,col_train,surv_train,cv=10,scoring='accuracy')
    cross_val_SVM.append(round(result_rf.mean()*100,2))
    
print('average accuracy SVM is', np.mean(SVM_score))
print('avergae cross_val_SVM is', np.mean(cross_val_SVM))


y_pred = cross_val_predict(clf,col_train,surv_train,cv=10)
sns.heatmap(confusion_matrix(col_train,y_pred),annot=True,fmt='3.0f',cmap="summer")
plt.title('Confusion_matrix for random forest', y=1.05, size=15)
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'standardscaler', 'linearsvc', 'standardscaler__copy', 'standardscaler__with_mean', 'standardscaler__with_std', 'linearsvc__C', 'linearsvc__class_weight', 'linearsvc__dual', 'linearsvc__fit_intercept', 'linearsvc__intercept_scaling', 'linearsvc__loss', 'linearsvc__max_iter', 'linearsvc__multi_class', 'linearsvc__penalty', 'linearsvc__random_state', 'linearsvc__tol', 'linearsvc__verbose'])
# C:\Users\Marlon\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Marlon\AppData\Roaming\Python\Python38\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...
